# %%
x=[]
scale=1000
for i in range(1,5):
    x.append(3*i*scale)
print(x)
# Out:
# [3000, 6000, 9000, 12000]

# %%
from random import randint
import matplotlib.pyplot as plt
import math

# %%
xavg=[5,19,50,86]
xworst=[9,31,70,140]
xbest=[2,12,26,39]
plt.plot(x,xworst,label='Worst case')
plt.plot(x,xavg,label='Average Case')
plt.plot(x,xbest,label='Best Case')
plt.legend()
plt.title("Bubble Sort Times")
plt.savefig("DSBubbleSortTime.png",dpi=300)
plt.show()

# %%
xavg=[4498500,17997000,40495500,71994000]
xworst=[4498500,17997000,40495500,71994000]
xbest=[4498500,17997000,40495500,71994000]
plt.plot(x,xworst,label='Worst case',alpha=1)
plt.plot(x,xavg,label='Average Case',alpha=0.7)
plt.plot(x,xbest,label='Best Case',alpha=0.5)
plt.legend()
plt.title("Bubble Sort Comparisons")
plt.savefig("DSBubbleSortComparison.png",dpi=300)
plt.show()

# %%
xavg=[2246574,8953408,20268792,35850371]
xworst=[4498500,17997000,40495500,71994000]
xbest=[0,0,0,0]
plt.plot(x,xworst,label='Worst case')
plt.plot(x,xavg,label='Average Case')
plt.plot(x,xbest,label='Best Case')
plt.legend()
plt.title("Bubble Sort Swaps")
plt.savefig("DSBubbleSortSwaps.png",dpi=300)
plt.show()

# %%
xavg=[2248077,8886813,19889369,35497844]
xworst=[4498500,17997000,40495500,71994000]
xbest=[299999,599999,899999,1199999]
plt.plot(x,xworst,label='Worst case')
plt.plot(x,xavg,label='Average Case')
plt.plot(x,xbest,label='Best Case')
plt.legend()
plt.title("Insertion Sort Swaps")
plt.savefig("DSInsertionSortSwaps.png",dpi=300)
plt.show()

# %%
xavg=[2251076,8892812,19898368,35509843]
xworst=[4501499,18002999,40504499,72005999]
xbest=[299999,599999,899999,1199999]
plt.plot(x,xworst,label='Worst case')
plt.plot(x,xavg,label='Average Case')
plt.plot(x,xbest,label='Best Case')
plt.legend()
plt.title("Insertion Sort Comparisons")
plt.savefig("DSInsertionSortComparisons.png",dpi=300)
plt.show()

# %%
xbest=[997,1001,1004,1007]
xworst=[18999,50002,128010,242018]
xavg=[9999,26003,60004,169010]
plt.plot(x,xworst,label='Worst case')
plt.plot(x,xavg,label='Average Case')
plt.plot(x,xbest,label='Best Case')
plt.legend()
plt.title("Insertion Sort Time Taken")
plt.savefig("DSInsertionSortTimeTaken.png",dpi=300)
plt.show()

# %%
xbest=[9999,40002,90007,180014]
xworst=[14999,47002,97007,193013]
xavg=[12995,42011,95006,190013]
plt.plot(x,xworst,label='Worst case')
plt.plot(x,xavg,label='Average Case')
plt.plot(x,xbest,label='Best Case')
plt.legend()
plt.title("Selection Sort Time Taken")
plt.savefig("DSSelectionSortTimeTaken.png",dpi=300)
plt.show()

# %%
xbest=[2999,5999,8999,11999]
xworst=[2999,5999,8999,11999]
xavg=[2999,5999,8999,11999]
plt.plot(x,xworst,label='Worst case')
plt.plot(x,xavg,label='Average Case',alpha=0.5)
plt.plot(x,xbest,label='Best Case')
plt.legend()
plt.title("Selection Sort Swaps")
plt.savefig("DSSelectionSortSwaps.png",dpi=300)
plt.show()

# %%
xbest=[4498500,17997000,40495500,71994000]
xworst=[4498500,17997000,40495500,71994000]
xavg=[4498500,17997000,40495500,71994000]
plt.plot(x,xworst,label='Worst case',alpha=0.5)
plt.plot(x,xavg,label='Average Case',alpha=0.5)
plt.plot(x,xbest,label='Best Case',alpha=0.5)
plt.legend()
plt.title("Selection Sort Comparisons")
plt.savefig("DSSelectionSortComparisons.png",dpi=300)
plt.show()

# %%
xbest=[4498500,22495500,62991000,134985000]
xworst=[4498500,22495500,62991000,134985000]
xavg=[2717090,8261740,16979880,29276360]
plt.plot(x,xworst,label='Worst case')
plt.plot(x,xavg,label='Average Case')
plt.plot(x,xbest,'go-',label='Best Case',alpha=0.5)
plt.legend()
plt.title("Quick Sort Comparisons")
plt.savefig("DSQuickSortComparisons.png",dpi=300)
plt.show()

# %%
xbest=[4501499,22504498,63008997,135014996]
xworst=[2251499,11254498,31508997,67514996]
xavg=[20794,69490,139133,244968]
plt.plot(x,xworst,label='Worst case')
plt.plot(x,xavg,label='Average Case')
plt.plot(x,xbest,label='Best Case')
plt.legend()
plt.title("Quick Sort Swaps")
plt.savefig("DSQuickSortSwaps.png",dpi=300)
plt.show()

# %%
xbest=[35000,178015,414022,727054]
xworst=[28003,112006,248022,473035]
xavg=[5000,7999,15000,18000]
#xspec=[]
#for i in range(0,len(x)):
#   xspec.append(x[i]*100)
plt.plot(x,xworst,label='Worst case')
plt.plot(x,xavg,label='Average Case')
plt.plot(x,xbest,label='Best Case')
plt.legend()
plt.title("Quick Sort Time")
plt.savefig("DSQuickSortTime.png",dpi=300)
plt.show()

# %%
xbest=[3985,6998,10999,16001]
xworst=[3999,7000,11001,15999]
xavg=[6999,10004,14005,20002]
plt.plot(x,xworst,label='Worst case')
plt.plot(x,xavg,label='Average Case')
plt.plot(x,xbest,label='Best Case')
plt.legend()
plt.title("Merge Sort Time")
plt.savefig("DSMergeSortTime.png",dpi=300)
plt.show()

# %%
xbest=[227728,713184,1478432,2509344]
xworst=[219504,688512,1412192,2410208]
xavg=[408601,1285939,2655204,4529532]
plt.plot(x,xworst,label='Worst case')
plt.plot(x,xavg,label='Average Case')
plt.plot(x,xbest,label='Best Case')
plt.legend()
plt.title("Merge Sort Comparisons")
plt.savefig("DSMergeSortComparisons.png",dpi=300)
plt.show()

# %%
xbest=[447232,1401696,2890624,4919552]
xworst=[447232,1401696,2890624,4919552]
xavg=[447232,1401696,2890624,4919552]
plt.plot(x,xworst,label='Worst case')
plt.plot(x,xavg,label='Average Case',alpha=0.7)
plt.plot(x,xbest,label='Best Case')
plt.legend()
plt.title("Merge Sort Swaps")
plt.savefig("DSMergeSortSwaps.png",dpi=300)
plt.show()
